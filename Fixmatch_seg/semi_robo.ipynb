# %%
# !nvidia-smi
# Out:
# Sun Mar 13 17:45:13 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
os.chdir("/content/drive/My Drive/CCT")

# %%
pip install dominate

# %%
# !python train.py --config configs/config_robust.json
# Out:
# python3: can't open file 'train.py': [Errno 2] No such file or directory

# %%
import numpy as np
from PIL import Image
a=np.asarray(Image.open('/content/drive/MyDrive/robustmislite/Training/Rectalresection/10/101004/instrument_instances.png'), dtype=np.int32)+1
np.unique(a)
# Out:
# array([1, 2], dtype=int32)

# %%
get_voc_pallete(21)
# Out:
# [0,
#  0,
#  0,
#  128,
#  0,
#  0,
#  0,
#  128,
#  0,
#  128,
#  128,
#  0,
#  0,
#  0,
#  128,
#  128,
#  0,
#  128,
#  0,
#  128,
#  128,
#  128,
#  128,
#  128,
#  64,
#  0,
#  0,
#  192,
#  0,
#  0,
#  64,
#  128,
#  0,
#  192,
#  128,
#  0,
#  64,
#  0,
#  128,
#  192,
#  0,
#  128,
#  64,
#  128,
#  128,
#  192,
#  128,
#  128,
#  0,
#  64,
#  0,
#  128,
#  64,
#  0,
#  0,
#  192,
#  0,
#  128,
#  192,
#  0,
#  0,
#  64,
#  128]
